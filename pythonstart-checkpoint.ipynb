# %% [markdown]
# Alberto Melendez
# =================
#
# #### Task 1
# [Geo-Python](https://geo-python.github.io/2018/), is interesting since it focuses on how Python can be used in geo-fields like geophysics, geology and geography. Also goes over the use of packages that seem critical for these respective fields such as NumPy, Pandas, and MapPlotLib (which I mention later in Task 2). It even goes over debugging and errors which I think is very important for coding since it may save time on researching what is causing issues in one's code.
#
# #### Task 2
# A) [SQLAlchemy](https://pypi.org/project/SQLAlchemy/), works with SQL databases which provides a full load of capabilities and
#    access to the databases including relational mapping.
#
#    [NumPy](http://www.numpy.org), a scientific computing library that reads arbitary values, serves a multi-dimensional array
#    object for the data analysis and manipulation. Contains tools that work with C/C++ and Fortran code, also have Fourier
#    transform and random number capabilities.
#
#    [Twisted](https://twistedmatrix.com/trac/), is an event-driven networking library that makes adding networking applications
#    into python code easy. Supporting network protocols include: SMTP, POP3, IMAP, SSHv2, and DNS.
#
# B) [MapPlotLib](https://matplotlib.org/), is a library that plots in 2D with only a few lines of code. You can create
#    interactive navigationt tools with it as well. The library even has toolkits that can used to accomplish more specific goals
#    including 3D plotting!
#
#    [Bokeh](http://bokeh.pydata.org/en/latest/), is another library that works like ggplot but is geared
#    more towards web browsers and strives to make the data visualization both functionally and aesthetically pleasing.
#
# C) [Pandas](https://pandas.pydata.org/), a library that works with dataframes utilizes a wide variety of Python libraries to
#    accomplish specific tasks in statistical analysis, visualization, domain specifics, and API use.

# %%
## Part 3
#### Task 4

greet = "Hello World, this is Alberto!"

print(greet)

#### Task 5

age = 25

age_start = " I am "

age_end = " years old!"

age_str = str(age)

long_sentence = greet + age_start + age_str + age_end

print(long_sentence.upper())

#### Task 6

sentence_list = [greet, age_start, age_str, age_end]

num_char = sentence_list.count("a")

list_to_str = " ".join(sentence_list)

#### Task 7

first_half = len(long_sentence) / 2

string_half = long_sentence[0:first_half]

print(string_half)

#### Task 8

num_remove = list_to_str.replace(" 25 ", "")

print(num_remove)

word_replace = num_remove.replace(" years", "not")

word_replace2 = word_replace.replace("  I", " I")

print(word_replace2)

#### Task 9

delimiter = " "

word_split = delimiter.split(word_replace2)

add_word = word_split.insert(5, "Melendez") 

#### Task 10

import random

x = random.randint(1, 100)

print(x)

if x <= 25:
    print("1st Quartile")
elif 25 < x <= 50:
    print("2nd Quartile")
elif 50 < x <= 75:
    print("3rd Quartile")
elif 75 < x <= 100:
    print("4th Quartile")
    
## Part 4
### Task 11

city_list = ["Seattle", "Buffalo", "Portland", "Atlanta", "Miami", "Detroit"]

for city in city_list:
    print("Warning, residents of " + city + 
          " temperatures will reach sub-zero temperatures today, please stay indoors if possible")

#### Task 12

result_list = []

state = ["Washington", "California", "Nevada", "Idaho", "Montana", "Utah", "Colorado", "New Mexico"]

for result_list in state:
    print("C://Users/Alberto/Documents/Geog458/" + result_list +".shp")

#### Task 13 stop exactly at zero?

count = 10

while count:
    print ("T minus " + str(count))
    count -=1 

## Part 5
#### Task 14

def countdown(num):
    while num:
        print ("T minus " + str(num))
        num -=1

#### Task 15

def quartile_calc(a):
    if a < 0:
        print("Error")
    elif a <= 25:
        print("1st Quartile")
    elif 25 < a <= 50:
        print("2nd Quartile")
    elif 50 < a <= 75:
        print("3rd Quartile")
    elif 75 < a <= 100:
        print("4th Quartile")
    elif a > 100:
        print("Error")
# Out:
# Hello World, this is Alberto!
# HELLO WORLD, THIS IS ALBERTO! I AM 25 YEARS OLD!
# Hello World, this is Alb
# Hello World, this is Alberto!  I am  years old!
# Hello World, this is Alberto! I am not old!
# 38
# 2nd Quartile
# Warning, residents of Seattle temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning, residents of Buffalo temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning, residents of Portland temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning, residents of Atlanta temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning, residents of Miami temperatures will reach sub-zero temperatures today, please stay indoors if possible
# Warning, residents of Detroit temperatures will reach sub-zero temperatures today, please stay indoors if possible
# C://Users/Alberto/Documents/Geog458/Washington.shp
# ...
